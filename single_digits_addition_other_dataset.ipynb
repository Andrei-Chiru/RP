# %% [markdown]
# # EMNIST Digit Addition Problem

# %%
import tensorflow as tf
import ltn
import baselines, data, commons
import matplotlib.pyplot as plt
from collections import defaultdict

# GET DATA
ds_train, ds_test = data.get_op_dataset(
        data_loader_fn = data.get_emnist_digits_as_numpy,
        count_train    = 3000,
        count_test     = 1000,
        buffer_size    = 3000,
        batch_size     = 16,
        n_operands     = 2,
        op             = lambda args: args[0] + args[1] 
)


# MODELS FOR CLASSIFYING DIGIT
logits_model = baselines.SingleDigit(inputs_as_a_list=True)
Digit = ltn.Predicate.FromLogits(logits_model, activation_function="softmax")

# DECLARING VARIABLES AND LOGICAL OPERATORS
d1 = ltn.Variable("digits1", range(10))
d2 = ltn.Variable("digits2", range(10))

Not = ltn.Wrapper_Connective(ltn.fuzzy_ops.Not_Std())
And = ltn.Wrapper_Connective(ltn.fuzzy_ops.And_Prod())
Or = ltn.Wrapper_Connective(ltn.fuzzy_ops.Or_ProbSum())
Implies = ltn.Wrapper_Connective(ltn.fuzzy_ops.Implies_Reichenbach())
Forall = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMeanError(),semantics="forall")
Exists = ltn.Wrapper_Quantifier(ltn.fuzzy_ops.Aggreg_pMean(),semantics="exists")

# MASKS
add = ltn.Function.Lambda(lambda inputs: inputs[0]+inputs[1])
equals = ltn.Predicate.Lambda(lambda inputs: inputs[0] == inputs[1])

# AXIOMS
@tf.function
def axioms(images_x, images_y, labels_z, p_schedule=tf.constant(2.)):
    images_x = ltn.Variable("x", images_x)
    images_y = ltn.Variable("y", images_y)
    labels_z = ltn.Variable("z", labels_z)
    axiom = Forall(
            ltn.diag(images_x,images_y,labels_z),
            Exists(
                (d1,d2),
                And(Digit([images_x,d1]),Digit([images_y,d2])),
                mask=equals([add([d1,d2]), labels_z]),
                p=p_schedule
            ),
            p=2
        )
    sat = axiom.tensor
    return sat

images_x, images_y, labels_z = next(ds_train.as_numpy_iterator())
axioms(images_x, images_y, labels_z)


# OPTIMISER, TRAINING AND TEST STEP
optimizer = tf.keras.optimizers.Adam(0.001)
metrics_dict = {
    'train_loss': tf.keras.metrics.Mean(name="train_loss"),
    'train_accuracy': tf.keras.metrics.Mean(name="train_accuracy"),
    'test_loss': tf.keras.metrics.Mean(name="test_loss"),
    'test_accuracy': tf.keras.metrics.Mean(name="test_accuracy")    
}

@tf.function
def train_step(images_x, images_y, labels_z, **parameters):
    # loss
    with tf.GradientTape() as tape:
        loss = 1.- axioms(images_x, images_y, labels_z, **parameters)
    gradients = tape.gradient(loss, logits_model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, logits_model.trainable_variables))
    metrics_dict['train_loss'](loss)
    # accuracy
    predictions_x = tf.argmax(logits_model([images_x]),axis=-1)
    predictions_y = tf.argmax(logits_model([images_y]),axis=-1)
    predictions_z = predictions_x + predictions_y
    match = tf.equal(predictions_z,tf.cast(labels_z,predictions_z.dtype))
    metrics_dict['train_accuracy'](tf.reduce_mean(tf.cast(match,tf.float32)))
    
@tf.function
def test_step(images_x, images_y, labels_z, **parameters):
    # loss
    loss = 1.- axioms(images_x, images_y, labels_z, **parameters)
    metrics_dict['test_loss'](loss)
    # accuracy
    predictions_x = tf.argmax(logits_model([images_x]),axis=-1)
    predictions_y = tf.argmax(logits_model([images_y]),axis=-1)
    predictions_z = predictions_x + predictions_y
    match = tf.equal(predictions_z,tf.cast(labels_z,predictions_z.dtype))
    metrics_dict['test_accuracy'](tf.reduce_mean(tf.cast(match,tf.float32)))
    
# SETTING THE PARAMETER
scheduled_parameters = defaultdict(lambda: {})
for epoch in range(0,4):
    scheduled_parameters[epoch] = {"p_schedule":tf.constant(1.)}
for epoch in range(4,8):
    scheduled_parameters[epoch] = {"p_schedule":tf.constant(2.)}
for epoch in range(8,12):
    scheduled_parameters[epoch] = {"p_schedule":tf.constant(4.)}
for epoch in range(12,20):
    scheduled_parameters[epoch] = {"p_schedule":tf.constant(6.)}
    
# TRAINING THE MODEL
commons.train(
    20,
    metrics_dict,
    ds_train,
    ds_test,
    train_step,
    test_step,
    scheduled_parameters=scheduled_parameters
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 65
#      62     return sat
#      64 images_x, images_y, labels_z = next(ds_train.as_numpy_iterator())
# ---> 65 axioms(images_x, images_y, labels_z)
#      68 # OPTIMISER, TRAINING AND TEST STEP
#      69 optimizer = tf.keras.optimizers.Adam(0.001)
#
# File ~\Desktop\RP\environment\Lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_filefpri_q4a.py:13, in outer_factory.<locals>.inner_factory.<locals>.tf__axioms(images_x, images_y, labels_z, p_schedule)
#      11 images_y = ag__.converted_call(ag__.ld(ltn).Variable, ('y', ag__.ld(images_y)), None, fscope)
#      12 labels_z = ag__.converted_call(ag__.ld(ltn).Variable, ('z', ag__.ld(labels_z)), None, fscope)
# ---> 13 axiom = ag__.converted_call(ag__.ld(Forall), (ag__.converted_call(ag__.ld(ltn).diag, (ag__.ld(images_x), ag__.ld(images_y), ag__.ld(labels_z)), None, fscope), ag__.converted_call(ag__.ld(Exists), ((ag__.ld(d1), ag__.ld(d2)), ag__.converted_call(ag__.ld(And), (ag__.converted_call(ag__.ld(Digit), ([ag__.ld(images_x), ag__.ld(d1)],), None, fscope), ag__.converted_call(ag__.ld(Digit), ([ag__.ld(images_y), ag__.ld(d2)],), None, fscope)), None, fscope)), dict(mask=ag__.converted_call(ag__.ld(equals), ([ag__.converted_call(ag__.ld(add), ([ag__.ld(d1), ag__.ld(d2)],), None, fscope), ag__.ld(labels_z)],), None, fscope), p=ag__.ld(p_schedule)), fscope)), dict(p=2), fscope)
#      14 sat = ag__.ld(axiom).tensor
#      15 try:
#
# File ~\AppData\Local\Temp\__autograph_generated_filezpmtxvwz.py:61, in outer_factory.<locals>.inner_factory.<locals>.tf____call__(self, inputs, *args, **kwargs)
#      59 x = ag__.Undefined('x')
#      60 ag__.if_stmt(ag__.not_(ag__.converted_call(ag__.ld(isinstance), (ag__.ld(inputs), (ag__.ld(list), ag__.ld(tuple))), None, fscope)), if_body_2, else_body_2, get_state_3, set_state_3, (), 0)
# ---> 61 expr = ag__.converted_call(ag__.converted_call(ag__.ld(super), (), None, fscope).__call__, (ag__.ld(inputs),) + tuple(ag__.ld(args)), dict(**ag__.ld(kwargs)), fscope)
#      62 wff = ag__.converted_call(ag__.ld(Formula), (ag__.ld(expr).tensor, ag__.ld(expr).free_vars), None, fscope)
#      63 try:
#
# File ~\AppData\Local\Temp\__autograph_generated_file_2acfow9.py:32, in outer_factory.<locals>.inner_factory.<locals>.tf____call__(self, inputs, *args, **kwargs)
#      30 t_outputs = ag__.Undefined('t_outputs')
#      31 flat_inputs = ag__.Undefined('flat_inputs')
# ---> 32 ag__.if_stmt(ag__.not_(ag__.converted_call(ag__.ld(isinstance), (ag__.ld(inputs), (ag__.ld(list), ag__.ld(tuple))), None, fscope)), if_body, else_body, get_state, set_state, ('inputs', 't_outputs'), 2)
#      33 free_dims = ag__.converted_call(ag__.ld(tf).cast, (ag__.converted_call(ag__.ld(tf).shape, (ag__.ld(inputs)[0].tensor,), None, fscope)[:ag__.converted_call(ag__.ld(len), (ag__.ld(inputs)[0].free_vars,), None, fscope)], ag__.ld(tf).int32), None, fscope)
#      35 def get_state_1():
#
# File ~\AppData\Local\Temp\__autograph_generated_file_2acfow9.py:29, in outer_factory.<locals>.inner_factory.<locals>.tf____call__.<locals>.else_body()
#      27 inputs = ag__.converted_call(ag__.ld(broadcast_exprs), (ag__.ld(inputs),), None, fscope)
#      28 flat_inputs = ag__.converted_call(ag__.ld(_flatten_free_dims), (ag__.ld(inputs),), None, fscope)
# ---> 29 t_outputs = ag__.converted_call(ag__.ld(self).model, (ag__.converted_call(ag__.ld(as_tensors), (ag__.ld(flat_inputs),), None, fscope),) + tuple(ag__.ld(args)), dict(**ag__.ld(kwargs)), fscope)
#
# File ~\Desktop\RP\environment\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\anaconda3\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# ValueError: in user code:
#
#     File "C:\Users\andre\AppData\Local\Temp\ipykernel_8452\167330655.py", line 51, in axioms  *
#         axiom = Forall(
#     File "C:\Users\andre\Desktop\RP\environment\Lib\site-packages\ltn\core.py", line 189, in __call__  *
#         expr = super().__call__(inputs, *args, **kwargs)
#     File "C:\Users\andre\Desktop\RP\environment\Lib\site-packages\ltn\core.py", line 159, in __call__  *
#         t_outputs = self.model(as_tensors(flat_inputs), *args, **kwargs)
#     File "C:\Users\andre\Desktop\RP\environment\Lib\site-packages\keras\src\utils\traceback_utils.py", line 122, in error_handler  **
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\andre\anaconda3\Lib\contextlib.py", line 138, in __enter__
#         except StopIteration:
#
#     ValueError: '__softmax_tf_model_1' is not a valid root scope name. A root scope name has to match the following pattern: ^[A-Za-z0-9.][A-Za-z0-9_.\\/>-]*$
